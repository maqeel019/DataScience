# %% [raw]
#                                     MATPLOTLIB

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,10,1000)
y = np.sin(x)
plt.plot(x,y) #line form
plt.scatter(x[::10],y[::10] , color = 'purple') # scatter/dot form

# %%
# plt.plot(x,y,color='red')
# plt.plot(x,np.cos(x),color='green')
plt.plot(x[:100],y[:100], '-g') #solid green line
plt.plot(x[:300],y[:300] , '-b') #dashed green line
plt.plot(x[:500],y[:500] , '-r') #dashdot green line
plt.plot(x[:700],y[:700], '-p') #dotted green line

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('pythonvs/stocks.csv')
df.rename(columns={'Company Name':'Company' , 
                     'Earnings Per Share':'E/S', ' Book Value':'B.Value'},inplace=True )
company = df2['Company'].unique()
plt.scatter(np.arange(0 , len(df)),df['Price'],color='red'  , label="Priceee")
plt.scatter(np.arange(0 , len(df)),df['E/S'],color='green'  , label="Earnong")
plt.scatter(np.arange(0 , len(df)),df['B.Value'],color='brown'  , label="Priceee")

# %%
nu = np.arange(50,100)
index = np.arange(100,50,-1)

val = np.arange(10,40)
ind = np.arange(40,10, -1)

for container in ax.containers:
    ax.bar_label(container)
 
fig,ax = plt.subplots(figsize = (10,6))

ax.bar(nu , index , color = 'red' , label = 'Heck Value')
ax.bar(nu ,ind , color = 'green',label = 'Neck Value' )

ax.set_title("Value")
ax.set_ylabel("Y Value")
ax.set_xlabel("X Value")

ax.legend()
ax.grid(axis='y', linestyle='--', linewidth=1.5)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 13
#      10 fig,ax = plt.subplots(figsize = (10,6))
#      12 ax.bar(nu , index , color = 'red' , label = 'Heck Value')
# ---> 13 ax.bar(nu ,ind , color = 'green',label = 'Neck Value' )
#      15 ax.set_title("Value")
#      16 ax.set_ylabel("Y Value")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate sample data
nu = np.arange(50, 100)
val = np.arange(10, 40)

# Create the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the first set of bars
ax.bar(np.arange(len(nu)), nu, color='red', label='Heck Value')

# Plot the second set of bars
ax.bar(np.arange(len(val)), val, color='green', label='Neck Value')

# Set title and labels
ax.set_title("Value")
ax.set_ylabel("Y Value")
ax.set_xlabel("X Value")

# Add legend and grid
ax.legend()
ax.grid(axis='y', linestyle='--', linewidth=1.5)

plt.tight_layout()
plt.show()
